# %% [markdown]
# This notebook has stacking implementation with the following metalearners for multiclass classification:
# 1. TabNet

# %% [markdown]
# # Imports & Dataset Setup

# %%
import numpy as np
import optuna
from optuna import Trial, visualization
seed = 42
np.random.seed(seed)
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, roc_auc_score, balanced_accuracy_score, classification_report
from sklearn.model_selection import PredefinedSplit, GridSearchCV, RandomizedSearchCV
from scipy.stats import uniform, randint
import torch
import matplotlib.pyplot as plt

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
# !pip install -q pytorch_tabnet

# %%
from pytorch_tabnet.multitask import TabNetMultiTaskClassifier
from pytorch_tabnet.tab_model import TabNetClassifier

# %%
m_mobilenet_train = pd.read_csv("/kaggle/input/fork-of-koa-mobilenetv2/m_mobilenet_train.csv").drop(columns=['Unnamed: 0'])
m_mobilenet_val = pd.read_csv("/kaggle/input/fork-of-koa-mobilenetv2/m_mobilenet_val.csv").drop(columns=['Unnamed: 0'])
m_mobilenet_test = pd.read_csv("/kaggle/input/fork-of-koa-mobilenetv2/m_mobilenet_test.csv").drop(columns=['Unnamed: 0'])

# %%
m_densenet_train = pd.read_csv("/kaggle/input/koa-densenet-preds/m_densenet_train.csv").drop(columns=['Unnamed: 0'])
m_densenet_val = pd.read_csv("/kaggle/input/koa-densenet-preds/m_densenet_val.csv").drop(columns=['Unnamed: 0'])
m_densenet_test = pd.read_csv("/kaggle/input/koa-densenet-preds/m_densenet_test.csv").drop(columns=['Unnamed: 0'])

# %%
m_yolov8_train = pd.read_csv("/kaggle/input/koa-yolov8-preds/m_yolov8_train.csv").drop(columns=['Unnamed: 0'])
m_yolov8_val = pd.read_csv("/kaggle/input/koa-yolov8-preds/m_yolov8_val.csv").drop(columns=['Unnamed: 0'])
m_yolov8_test = pd.read_csv("/kaggle/input/koa-yolov8-preds/m_yolov8_test.csv").drop(columns=['Unnamed: 0'])

# %%
m_yolov8_train.rename(columns = {'FilePath': 'FileName'}, inplace=True)
m_yolov8_val.rename(columns = {'FilePath': 'FileName'}, inplace=True)
m_yolov8_test.rename(columns = {'FilePath': 'FileName'}, inplace=True)

# %%
train = m_mobilenet_train.merge(m_yolov8_train).merge(m_densenet_train)
val = m_mobilenet_val.merge(m_yolov8_val).merge(m_densenet_val)
test = m_mobilenet_test.merge(m_yolov8_test).merge(m_densenet_test)

# %%
X_train = train[['m_0', 'm_1', 'm_2', 'm_3', 'm_4', 'y_0', 'y_1', 'y_2', 'y_3', 'y_4', 'd_0', 'd_1', 'd_2', 'd_3', 'd_4']]
X_val = val[['m_0', 'm_1', 'm_2', 'm_3', 'm_4', 'y_0', 'y_1', 'y_2', 'y_3', 'y_4', 'd_0', 'd_1', 'd_2', 'd_3', 'd_4']]
X_test = test[['m_0', 'm_1', 'm_2', 'm_3', 'm_4', 'y_0', 'y_1', 'y_2', 'y_3', 'y_4', 'd_0', 'd_1', 'd_2', 'd_3', 'd_4']]
y_train = train[['y_true']]
y_val = val[['y_true']]
y_test = test[['y_true']]

# %% [markdown]
# # TabNet

# %%
X_train = X_train.to_numpy()
y_train = y_train.to_numpy().flatten().reshape(-1,1)

# %%
X_val= X_val.to_numpy()
y_val= y_val.to_numpy()
y_val= y_val.flatten()
y_val=y_val.reshape(len(y_val),1)

# %%
tabnet_params = {
                 "optimizer_fn":torch.optim.Adam,
                 "optimizer_params":dict(lr=2e-3),
                 "scheduler_params":{"step_size":50, 
                                 "gamma":0.9},
                 "scheduler_fn":torch.optim.lr_scheduler.StepLR,
                 "mask_type":'entmax',
                 "seed": seed
                }

clf = TabNetMultiTaskClassifier(**tabnet_params)

# %%
clf.fit(
    X_train=X_train, y_train=y_train,
    eval_set=[(X_train, y_train), (X_val, y_val)],
    eval_name=['train', 'valid'],
    max_epochs=200 , patience=0,
    batch_size=1024, virtual_batch_size=128,
    num_workers=0,
    drop_last=False # Optional, just an example of list usage
)
# Out:
# epoch 0  | loss: 1.72672 | train_logloss: 1.59694 | valid_logloss: 1.606   |  0:00:00s
# epoch 1  | loss: 1.4005  | train_logloss: 1.52146 | valid_logloss: 1.54002 |  0:00:01s
# epoch 2  | loss: 1.20745 | train_logloss: 1.42974 | valid_logloss: 1.46744 |  0:00:02s
# epoch 3  | loss: 1.0203  | train_logloss: 1.34184 | valid_logloss: 1.40344 |  0:00:02s
# epoch 4  | loss: 0.85241 | train_logloss: 1.24302 | valid_logloss: 1.33693 |  0:00:03s
# epoch 5  | loss: 0.73541 | train_logloss: 1.13543 | valid_logloss: 1.27166 |  0:00:04s
# epoch 6  | loss: 0.66878 | train_logloss: 1.06111 | valid_logloss: 1.23024 |  0:00:04s
# epoch 7  | loss: 0.61468 | train_logloss: 1.01397 | valid_logloss: 1.20996 |  0:00:05s
# epoch 8  | loss: 0.58893 | train_logloss: 0.98658 | valid_logloss: 1.19992 |  0:00:06s
# epoch 9  | loss: 0.5459  | train_logloss: 0.95767 | valid_logloss: 1.19363 |  0:00:06s
# epoch 10 | loss: 0.52946 | train_logloss: 0.93408 | valid_logloss: 1.18725 |  0:00:07s
# epoch 11 | loss: 0.51087 | train_logloss: 0.90728 | valid_logloss: 1.18105 |  0:00:08s
# epoch 12 | loss: 0.48509 | train_logloss: 0.87922 | valid_logloss: 1.17804 |  0:00:08s
# epoch 13 | loss: 0.46718 | train_logloss: 0.85453 | valid_logloss: 1.17537 |  0:00:09s
# epoch 14 | loss: 0.45287 | train_logloss: 0.82834 | valid_logloss: 1.17267 |  0:00:09s
# epoch 15 | loss: 0.43988 | train_logloss: 0.81205 | valid_logloss: 1.17874 |  0:00:10s
# epoch 16 | loss: 0.42364 | train_logloss: 0.79328 | valid_logloss: 1.18365 |  0:00:11s
# epoch 17 | loss: 0.41483 | train_logloss: 0.77736 | valid_logloss: 1.18481 |  0:00:11s
# epoch 18 | loss: 0.40541 | train_logloss: 0.75924 | valid_logloss: 1.18471 |  0:00:12s
# epoch 19 | loss: 0.39404 | train_logloss: 0.73748 | valid_logloss: 1.18394 |  0:00:13s
# epoch 20 | loss: 0.38822 | train_logloss: 0.72637 | valid_logloss: 1.18463 |  0:00:13s
# epoch 21 | loss: 0.38792 | train_logloss: 0.7075  | valid_logloss: 1.18249 |  0:00:14s
# epoch 22 | loss: 0.38613 | train_logloss: 0.68719 | valid_logloss: 1.17086 |  0:00:15s
# epoch 23 | loss: 0.37672 | train_logloss: 0.67215 | valid_logloss: 1.16316 |  0:00:15s
# epoch 24 | loss: 0.37791 | train_logloss: 0.65956 | valid_logloss: 1.15981 |  0:00:16s
# epoch 25 | loss: 0.37286 | train_logloss: 0.64634 | valid_logloss: 1.15739 |  0:00:16s
# epoch 26 | loss: 0.37464 | train_logloss: 0.63809 | valid_logloss: 1.16326 |  0:00:17s
# epoch 27 | loss: 0.37025 | train_logloss: 0.62863 | valid_logloss: 1.16289 |  0:00:18s
# epoch 28 | loss: 0.36985 | train_logloss: 0.61499 | valid_logloss: 1.15999 |  0:00:18s
# epoch 29 | loss: 0.36605 | train_logloss: 0.60359 | valid_logloss: 1.15602 |  0:00:19s
# epoch 30 | loss: 0.36378 | train_logloss: 0.58825 | valid_logloss: 1.15405 |  0:00:20s
# epoch 31 | loss: 0.36296 | train_logloss: 0.57275 | valid_logloss: 1.15277 |  0:00:20s
# epoch 32 | loss: 0.36337 | train_logloss: 0.56188 | valid_logloss: 1.15714 |  0:00:21s
# epoch 33 | loss: 0.36037 | train_logloss: 0.55097 | valid_logloss: 1.16275 |  0:00:22s
# epoch 34 | loss: 0.36326 | train_logloss: 0.54319 | valid_logloss: 1.16446 |  0:00:22s
# epoch 35 | loss: 0.35448 | train_logloss: 0.53023 | valid_logloss: 1.15964 |  0:00:23s
# epoch 36 | loss: 0.35586 | train_logloss: 0.52262 | valid_logloss: 1.16293 |  0:00:24s
# epoch 37 | loss: 0.35767 | train_logloss: 0.50921 | valid_logloss: 1.16011 |  0:00:24s
# epoch 38 | loss: 0.35593 | train_logloss: 0.49729 | valid_logloss: 1.16042 |  0:00:25s
# epoch 39 | loss: 0.35524 | train_logloss: 0.48189 | valid_logloss: 1.14951 |  0:00:26s
# epoch 40 | loss: 0.35327 | train_logloss: 0.47287 | valid_logloss: 1.15045 |  0:00:26s
# epoch 41 | loss: 0.35051 | train_logloss: 0.45664 | valid_logloss: 1.1533  |  0:00:27s
# epoch 42 | loss: 0.35406 | train_logloss: 0.44704 | valid_logloss: 1.15229 |  0:00:28s
# epoch 43 | loss: 0.35379 | train_logloss: 0.4386  | valid_logloss: 1.14939 |  0:00:29s
# epoch 44 | loss: 0.35139 | train_logloss: 0.43279 | valid_logloss: 1.15488 |  0:00:29s
# epoch 45 | loss: 0.35291 | train_logloss: 0.42728 | valid_logloss: 1.15856 |  0:00:30s
# epoch 46 | loss: 0.3499  | train_logloss: 0.42146 | valid_logloss: 1.16325 |  0:00:31s
# epoch 47 | loss: 0.34564 | train_logloss: 0.4147  | valid_logloss: 1.16606 |  0:00:31s
# epoch 48 | loss: 0.34887 | train_logloss: 0.40386 | valid_logloss: 1.16874 |  0:00:32s
# epoch 49 | loss: 0.35091 | train_logloss: 0.38982 | valid_logloss: 1.16121 |  0:00:33s
# epoch 50 | loss: 0.34885 | train_logloss: 0.37413 | valid_logloss: 1.16643 |  0:00:33s
# epoch 51 | loss: 0.34529 | train_logloss: 0.38834 | valid_logloss: 1.19766 |  0:00:34s
# epoch 52 | loss: 0.34358 | train_logloss: 0.38917 | valid_logloss: 1.21357 |  0:00:35s
# epoch 53 | loss: 0.34709 | train_logloss: 0.38916 | valid_logloss: 1.21961 |  0:00:35s
# epoch 54 | loss: 0.34543 | train_logloss: 0.38016 | valid_logloss: 1.21442 |  0:00:36s
# epoch 55 | loss: 0.34487 | train_logloss: 0.3613  | valid_logloss: 1.202   |  0:00:37s
# epoch 56 | loss: 0.34062 | train_logloss: 0.35612 | valid_logloss: 1.20667 |  0:00:37s
# epoch 57 | loss: 0.34531 | train_logloss: 0.35167 | valid_logloss: 1.21209 |  0:00:38s
# epoch 58 | loss: 0.34457 | train_logloss: 0.34306 | valid_logloss: 1.21215 |  0:00:39s
# epoch 59 | loss: 0.34436 | train_logloss: 0.34312 | valid_logloss: 1.21165 |  0:00:39s
# epoch 60 | loss: 0.34137 | train_logloss: 0.34396 | valid_logloss: 1.21495 |  0:00:40s
# epoch 61 | loss: 0.3418  | train_logloss: 0.33754 | valid_logloss: 1.23499 |  0:00:41s
# epoch 62 | loss: 0.34289 | train_logloss: 0.3353  | valid_logloss: 1.25306 |  0:00:41s
# epoch 63 | loss: 0.3399  | train_logloss: 0.33593 | valid_logloss: 1.26128 |  0:00:42s
# epoch 64 | loss: 0.34167 | train_logloss: 0.33586 | valid_logloss: 1.26031 |  0:00:42s
# epoch 65 | loss: 0.33859 | train_logloss: 0.33458 | valid_logloss: 1.25728 |  0:00:43s
# epoch 66 | loss: 0.34267 | train_logloss: 0.33352 | valid_logloss: 1.2601  |  0:00:44s
# epoch 67 | loss: 0.34001 | train_logloss: 0.33213 | valid_logloss: 1.27196 |  0:00:44s
# epoch 68 | loss: 0.34027 | train_logloss: 0.33145 | valid_logloss: 1.27425 |  0:00:45s
# epoch 69 | loss: 0.34207 | train_logloss: 0.33096 | valid_logloss: 1.27985 |  0:00:46s
# epoch 70 | loss: 0.34255 | train_logloss: 0.33033 | valid_logloss: 1.28107 |  0:00:46s
# epoch 71 | loss: 0.33703 | train_logloss: 0.32945 | valid_logloss: 1.29795 |  0:00:47s
# epoch 72 | loss: 0.33929 | train_logloss: 0.3291  | valid_logloss: 1.30378 |  0:00:48s
# epoch 73 | loss: 0.33473 | train_logloss: 0.32928 | valid_logloss: 1.31147 |  0:00:48s
# epoch 74 | loss: 0.33966 | train_logloss: 0.3288  | valid_logloss: 1.31966 |  0:00:49s
# epoch 75 | loss: 0.33269 | train_logloss: 0.32733 | valid_logloss: 1.33218 |  0:00:50s
# epoch 76 | loss: 0.33522 | train_logloss: 0.32684 | valid_logloss: 1.34639 |  0:00:50s
# epoch 77 | loss: 0.33889 | train_logloss: 0.32623 | valid_logloss: 1.35024 |  0:00:51s
# epoch 78 | loss: 0.33508 | train_logloss: 0.32721 | valid_logloss: 1.35625 |  0:00:52s
# epoch 79 | loss: 0.33538 | train_logloss: 0.32542 | valid_logloss: 1.36639 |  0:00:52s
# epoch 80 | loss: 0.33174 | train_logloss: 0.3254  | valid_logloss: 1.38714 |  0:00:53s
# epoch 81 | loss: 0.33769 | train_logloss: 0.32606 | valid_logloss: 1.38667 |  0:00:53s
# epoch 82 | loss: 0.33858 | train_logloss: 0.32533 | valid_logloss: 1.39688 |  0:00:54s
# epoch 83 | loss: 0.33199 | train_logloss: 0.32523 | valid_logloss: 1.39246 |  0:00:55s
# epoch 84 | loss: 0.33822 | train_logloss: 0.3244  | valid_logloss: 1.39432 |  0:00:56s
# epoch 85 | loss: 0.33586 | train_logloss: 0.32448 | valid_logloss: 1.38511 |  0:00:56s
# epoch 86 | loss: 0.33293 | train_logloss: 0.32444 | valid_logloss: 1.3953  |  0:00:57s
# epoch 87 | loss: 0.33655 | train_logloss: 0.32418 | valid_logloss: 1.39935 |  0:00:58s
# epoch 88 | loss: 0.33588 | train_logloss: 0.32369 | valid_logloss: 1.38361 |  0:00:58s
# epoch 89 | loss: 0.33579 | train_logloss: 0.32458 | valid_logloss: 1.37612 |  0:00:59s
# epoch 90 | loss: 0.33172 | train_logloss: 0.32319 | valid_logloss: 1.37844 |  0:00:59s
# epoch 91 | loss: 0.33568 | train_logloss: 0.32293 | valid_logloss: 1.37612 |  0:01:00s
# epoch 92 | loss: 0.33295 | train_logloss: 0.32333 | valid_logloss: 1.3719  |  0:01:01s
# epoch 93 | loss: 0.33366 | train_logloss: 0.32224 | valid_logloss: 1.3902  |  0:01:01s
# epoch 94 | loss: 0.3337  | train_logloss: 0.32334 | valid_logloss: 1.39404 |  0:01:02s
# epoch 95 | loss: 0.33434 | train_logloss: 0.32235 | valid_logloss: 1.4044  |  0:01:03s
# epoch 96 | loss: 0.33219 | train_logloss: 0.32186 | valid_logloss: 1.41141 |  0:01:03s
# epoch 97 | loss: 0.33088 | train_logloss: 0.32136 | valid_logloss: 1.41184 |  0:01:04s
# epoch 98 | loss: 0.33309 | train_logloss: 0.32217 | valid_logloss: 1.41943 |  0:01:05s
# epoch 99 | loss: 0.33224 | train_logloss: 0.32132 | valid_logloss: 1.42505 |  0:01:05s
# epoch 100| loss: 0.33209 | train_logloss: 0.32099 | valid_logloss: 1.42961 |  0:01:06s
# epoch 101| loss: 0.33058 | train_logloss: 0.3211  | valid_logloss: 1.42285 |  0:01:07s
# epoch 102| loss: 0.33522 | train_logloss: 0.32072 | valid_logloss: 1.41467 |  0:01:07s
# epoch 103| loss: 0.33078 | train_logloss: 0.32038 | valid_logloss: 1.41806 |  0:01:08s
# epoch 104| loss: 0.33311 | train_logloss: 0.32009 | valid_logloss: 1.42075 |  0:01:09s
# epoch 105| loss: 0.33152 | train_logloss: 0.31974 | valid_logloss: 1.43014 |  0:01:09s
# epoch 106| loss: 0.33072 | train_logloss: 0.31972 | valid_logloss: 1.41412 |  0:01:10s
# epoch 107| loss: 0.33116 | train_logloss: 0.31982 | valid_logloss: 1.41336 |  0:01:11s
# epoch 108| loss: 0.32777 | train_logloss: 0.31975 | valid_logloss: 1.41906 |  0:01:11s
# epoch 109| loss: 0.33081 | train_logloss: 0.31926 | valid_logloss: 1.43453 |  0:01:12s
# epoch 110| loss: 0.32622 | train_logloss: 0.31906 | valid_logloss: 1.44007 |  0:01:13s
# epoch 111| loss: 0.33063 | train_logloss: 0.31911 | valid_logloss: 1.44596 |  0:01:13s
# epoch 112| loss: 0.33187 | train_logloss: 0.31947 | valid_logloss: 1.44289 |  0:01:14s
# epoch 113| loss: 0.33122 | train_logloss: 0.31907 | valid_logloss: 1.44403 |  0:01:15s
# epoch 114| loss: 0.32919 | train_logloss: 0.31914 | valid_logloss: 1.45393 |  0:01:15s
# epoch 115| loss: 0.33003 | train_logloss: 0.32027 | valid_logloss: 1.44085 |  0:01:16s
# epoch 116| loss: 0.32667 | train_logloss: 0.31921 | valid_logloss: 1.4502  |  0:01:17s
# epoch 117| loss: 0.32909 | train_logloss: 0.31911 | valid_logloss: 1.45544 |  0:01:17s
# epoch 118| loss: 0.33197 | train_logloss: 0.31915 | valid_logloss: 1.45571 |  0:01:18s
# epoch 119| loss: 0.33051 | train_logloss: 0.31881 | valid_logloss: 1.45551 |  0:01:19s
# epoch 120| loss: 0.32807 | train_logloss: 0.31935 | valid_logloss: 1.46534 |  0:01:19s
# epoch 121| loss: 0.32807 | train_logloss: 0.3188  | valid_logloss: 1.44582 |  0:01:20s
# epoch 122| loss: 0.33008 | train_logloss: 0.31834 | valid_logloss: 1.4389  |  0:01:21s
# epoch 123| loss: 0.33009 | train_logloss: 0.31801 | valid_logloss: 1.43974 |  0:01:21s
# epoch 124| loss: 0.33267 | train_logloss: 0.31814 | valid_logloss: 1.43227 |  0:01:22s
# epoch 125| loss: 0.32742 | train_logloss: 0.31866 | valid_logloss: 1.43639 |  0:01:23s
# epoch 126| loss: 0.32812 | train_logloss: 0.3176  | valid_logloss: 1.43972 |  0:01:23s
# epoch 127| loss: 0.33708 | train_logloss: 0.31771 | valid_logloss: 1.4425  |  0:01:24s
# epoch 128| loss: 0.32995 | train_logloss: 0.31747 | valid_logloss: 1.43874 |  0:01:24s
# epoch 129| loss: 0.32538 | train_logloss: 0.31734 | valid_logloss: 1.44512 |  0:01:25s
# epoch 130| loss: 0.32821 | train_logloss: 0.31721 | valid_logloss: 1.45165 |  0:01:26s
# epoch 131| loss: 0.32637 | train_logloss: 0.31695 | valid_logloss: 1.42949 |  0:01:27s
# epoch 132| loss: 0.32567 | train_logloss: 0.31713 | valid_logloss: 1.42233 |  0:01:27s
# epoch 133| loss: 0.32657 | train_logloss: 0.31694 | valid_logloss: 1.41203 |  0:01:28s
# epoch 134| loss: 0.32542 | train_logloss: 0.31652 | valid_logloss: 1.40322 |  0:01:29s
# epoch 135| loss: 0.32588 | train_logloss: 0.31687 | valid_logloss: 1.40675 |  0:01:29s
# epoch 136| loss: 0.32828 | train_logloss: 0.31678 | valid_logloss: 1.43193 |  0:01:30s
# epoch 137| loss: 0.33225 | train_logloss: 0.31707 | valid_logloss: 1.44337 |  0:01:31s
# epoch 138| loss: 0.32506 | train_logloss: 0.31658 | valid_logloss: 1.46993 |  0:01:31s
# epoch 139| loss: 0.32584 | train_logloss: 0.31622 | valid_logloss: 1.46258 |  0:01:32s
# epoch 140| loss: 0.32802 | train_logloss: 0.31654 | valid_logloss: 1.4689  |  0:01:33s
# epoch 141| loss: 0.32391 | train_logloss: 0.31724 | valid_logloss: 1.45939 |  0:01:33s
# epoch 142| loss: 0.32613 | train_logloss: 0.31651 | valid_logloss: 1.4554  |  0:01:34s
# epoch 143| loss: 0.32479 | train_logloss: 0.31648 | valid_logloss: 1.4555  |  0:01:35s
# epoch 144| loss: 0.32571 | train_logloss: 0.31831 | valid_logloss: 1.44422 |  0:01:35s
# epoch 145| loss: 0.33639 | train_logloss: 0.31862 | valid_logloss: 1.45442 |  0:01:36s
# epoch 146| loss: 0.3305  | train_logloss: 0.31789 | valid_logloss: 1.45702 |  0:01:37s
# epoch 147| loss: 0.32776 | train_logloss: 0.31715 | valid_logloss: 1.46367 |  0:01:37s
# epoch 148| loss: 0.32957 | train_logloss: 0.31691 | valid_logloss: 1.46371 |  0:01:38s
# epoch 149| loss: 0.32714 | train_logloss: 0.31689 | valid_logloss: 1.46039 |  0:01:39s
# epoch 150| loss: 0.32736 | train_logloss: 0.31689 | valid_logloss: 1.45591 |  0:01:39s
# epoch 151| loss: 0.32528 | train_logloss: 0.31668 | valid_logloss: 1.45047 |  0:01:40s
# epoch 152| loss: 0.32533 | train_logloss: 0.31647 | valid_logloss: 1.45704 |  0:01:41s
# epoch 153| loss: 0.32351 | train_logloss: 0.31606 | valid_logloss: 1.46504 |  0:01:41s
# epoch 154| loss: 0.32656 | train_logloss: 0.31632 | valid_logloss: 1.48869 |  0:01:42s
# epoch 155| loss: 0.32848 | train_logloss: 0.31609 | valid_logloss: 1.4852  |  0:01:43s
# epoch 156| loss: 0.32667 | train_logloss: 0.31555 | valid_logloss: 1.47509 |  0:01:43s
# epoch 157| loss: 0.32265 | train_logloss: 0.31556 | valid_logloss: 1.46506 |  0:01:44s
# epoch 158| loss: 0.32301 | train_logloss: 0.31564 | valid_logloss: 1.4619  |  0:01:45s
# epoch 159| loss: 0.32498 | train_logloss: 0.31568 | valid_logloss: 1.46041 |  0:01:45s
# epoch 160| loss: 0.32516 | train_logloss: 0.31482 | valid_logloss: 1.46146 |  0:01:46s
# epoch 161| loss: 0.32641 | train_logloss: 0.31523 | valid_logloss: 1.46777 |  0:01:47s
# epoch 162| loss: 0.3233  | train_logloss: 0.31558 | valid_logloss: 1.45608 |  0:01:48s
# epoch 163| loss: 0.3222  | train_logloss: 0.31532 | valid_logloss: 1.4633  |  0:01:48s
# epoch 164| loss: 0.3216  | train_logloss: 0.31539 | valid_logloss: 1.47172 |  0:01:49s
# epoch 165| loss: 0.32241 | train_logloss: 0.3148  | valid_logloss: 1.46736 |  0:01:50s
# epoch 166| loss: 0.32414 | train_logloss: 0.31503 | valid_logloss: 1.47089 |  0:01:50s
# epoch 167| loss: 0.32175 | train_logloss: 0.31525 | valid_logloss: 1.49549 |  0:01:51s
# epoch 168| loss: 0.3237  | train_logloss: 0.31455 | valid_logloss: 1.51144 |  0:01:52s
# epoch 169| loss: 0.32374 | train_logloss: 0.31519 | valid_logloss: 1.50581 |  0:01:52s
# epoch 170| loss: 0.3221  | train_logloss: 0.3143  | valid_logloss: 1.51343 |  0:01:53s
# epoch 171| loss: 0.32279 | train_logloss: 0.31379 | valid_logloss: 1.52247 |  0:01:54s
# epoch 172| loss: 0.32165 | train_logloss: 0.31427 | valid_logloss: 1.51788 |  0:01:54s
# epoch 173| loss: 0.32506 | train_logloss: 0.31364 | valid_logloss: 1.51886 |  0:01:55s
# epoch 174| loss: 0.32333 | train_logloss: 0.3135  | valid_logloss: 1.52549 |  0:01:56s
# epoch 175| loss: 0.32462 | train_logloss: 0.31337 | valid_logloss: 1.52635 |  0:01:56s
# epoch 176| loss: 0.32377 | train_logloss: 0.31324 | valid_logloss: 1.51357 |  0:01:57s
# epoch 177| loss: 0.32021 | train_logloss: 0.31342 | valid_logloss: 1.50675 |  0:01:58s
# epoch 178| loss: 0.32038 | train_logloss: 0.3141  | valid_logloss: 1.50946 |  0:01:58s
# epoch 179| loss: 0.32454 | train_logloss: 0.31396 | valid_logloss: 1.51466 |  0:01:59s
# epoch 180| loss: 0.32252 | train_logloss: 0.31399 | valid_logloss: 1.51035 |  0:02:00s
# epoch 181| loss: 0.32212 | train_logloss: 0.31381 | valid_logloss: 1.51635 |  0:02:00s
# epoch 182| loss: 0.32117 | train_logloss: 0.31338 | valid_logloss: 1.53054 |  0:02:01s
# epoch 183| loss: 0.32332 | train_logloss: 0.31414 | valid_logloss: 1.54543 |  0:02:02s
# epoch 184| loss: 0.32148 | train_logloss: 0.31358 | valid_logloss: 1.53756 |  0:02:02s
# epoch 185| loss: 0.3217  | train_logloss: 0.31313 | valid_logloss: 1.5396  |  0:02:03s
# epoch 186| loss: 0.32165 | train_logloss: 0.31267 | valid_logloss: 1.55015 |  0:02:04s
# epoch 187| loss: 0.32103 | train_logloss: 0.31232 | valid_logloss: 1.55637 |  0:02:04s
# epoch 188| loss: 0.32223 | train_logloss: 0.31188 | valid_logloss: 1.56358 |  0:02:05s
# epoch 189| loss: 0.32127 | train_logloss: 0.31197 | valid_logloss: 1.5592  |  0:02:06s
# epoch 190| loss: 0.31981 | train_logloss: 0.31172 | valid_logloss: 1.54908 |  0:02:06s
# epoch 191| loss: 0.31971 | train_logloss: 0.31162 | valid_logloss: 1.55313 |  0:02:07s
# epoch 192| loss: 0.31842 | train_logloss: 0.31179 | valid_logloss: 1.54833 |  0:02:08s
# epoch 193| loss: 0.32371 | train_logloss: 0.31231 | valid_logloss: 1.5386  |  0:02:08s
# epoch 194| loss: 0.32177 | train_logloss: 0.31188 | valid_logloss: 1.54998 |  0:02:09s
# epoch 195| loss: 0.31901 | train_logloss: 0.31189 | valid_logloss: 1.55104 |  0:02:10s
# epoch 196| loss: 0.31953 | train_logloss: 0.3118  | valid_logloss: 1.54011 |  0:02:10s
# epoch 197| loss: 0.3228  | train_logloss: 0.31173 | valid_logloss: 1.55101 |  0:02:11s
# epoch 198| loss: 0.3188  | train_logloss: 0.31191 | valid_logloss: 1.55895 |  0:02:12s
# epoch 199| loss: 0.32221 | train_logloss: 0.31165 | valid_logloss: 1.56557 |  0:02:12s

# %%
from sklearn.metrics import accuracy_score, balanced_accuracy_score, roc_auc_score

# %%
print("Testing on training set:")
print("Accuracy: ", accuracy_score(y_train.flatten().reshape(-1,1),clf.predict(X_train)[0].astype('int').reshape(-1,1)).round(3))
print("Balanced Accuracy: ", balanced_accuracy_score(y_train.flatten().reshape(-1,1),clf.predict(X_train)[0].astype('int').reshape(-1,1)).round(3))
print("AUC:", roc_auc_score(y_train,clf.predict_proba(X_train)[0],multi_class='ovr').round(3))

print("\nTesting on validation set:")
print("Accuracy: ", accuracy_score(y_val.flatten().reshape(-1,1),clf.predict(X_val)[0].astype('int').reshape(-1,1)).round(3))
print("Balanced Accuracy: ", balanced_accuracy_score(y_val.flatten().reshape(-1,1),clf.predict(X_val)[0].astype('int').reshape(-1,1)).round(3))
print("AUC:", roc_auc_score(y_val,clf.predict_proba(X_val)[0],multi_class='ovr').round(3))

print("\nTesting on testing set:")
print("Accuracy: ", accuracy_score(y_test.to_numpy().flatten().reshape(-1,1),clf.predict(X_test.to_numpy())[0].astype('int').reshape(-1,1)).round(3))
print("Balanced Accuracy: ", balanced_accuracy_score(y_test.to_numpy().flatten().reshape(-1,1),clf.predict(X_test.to_numpy())[0].astype('int').reshape(-1,1)).round(3))
print("AUC:", roc_auc_score(y_test,clf.predict_proba(X_test.to_numpy())[0],multi_class='ovr').round(3))
# Out:
# Testing on training set:
# Accuracy:  0.873
# Balanced Accuracy:  0.891
# AUC: 0.978
#
# Testing on validation set:
# Accuracy:  0.607
# Balanced Accuracy:  0.626
# AUC: 0.811
#
# Testing on testing set:
# Accuracy:  0.708
# Balanced Accuracy:  0.723
# AUC: 0.889
