# %%
#import non tensorflow libraries
import matplotlib.pyplot as plt
import os
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import pathlib
import IPython.display as display

#import tensorflow libraries
import tensorflow as tf
from tensorflow import keras
# from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image_dataset_from_directory
import tensorflow.keras.layers as tfl
import pickle
# Out:
# 2024-04-14 18:00:16.533401: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-14 18:00:16.533561: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-14 18:00:16.657780: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
BATCH_SIZE = 16
IMG_SIZE = (224, 224)
train_dataset = image_dataset_from_directory('/kaggle/input/preprocessing-koa-dataset/new/train',
                                             label_mode="categorical",
                                             shuffle=True,
                                             batch_size=BATCH_SIZE,
                                             image_size=IMG_SIZE)
validation_dataset = image_dataset_from_directory('/kaggle/input/preprocessing-koa-dataset/new/val',
                                             label_mode="categorical",
                                             shuffle=True,
                                             batch_size=BATCH_SIZE,
                                             image_size=IMG_SIZE)
# Out:
# Found 7304 files belonging to 5 classes.
# Found 826 files belonging to 5 classes.

# %%
class_names = train_dataset.class_names

plt.figure(figsize=(5, 5))
for images, labels in train_dataset.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        print(labels[i])
#         plt.title(class_names[labels[i]])
        plt.axis("off")
# Out:
# tf.Tensor([1. 0. 0. 0. 0.], shape=(5,), dtype=float32)
# tf.Tensor([0. 0. 0. 1. 0.], shape=(5,), dtype=float32)
# tf.Tensor([0. 0. 1. 0. 0.], shape=(5,), dtype=float32)
# tf.Tensor([0. 0. 1. 0. 0.], shape=(5,), dtype=float32)
# tf.Tensor([1. 0. 0. 0. 0.], shape=(5,), dtype=float32)
# tf.Tensor([1. 0. 0. 0. 0.], shape=(5,), dtype=float32)
# tf.Tensor([0. 1. 0. 0. 0.], shape=(5,), dtype=float32)
# tf.Tensor([0. 0. 0. 1. 0.], shape=(5,), dtype=float32)
# tf.Tensor([0. 1. 0. 0. 0.], shape=(5,), dtype=float32)

# %%
def data_augmenter():
    '''
    Create a Sequential model composed of 2 layers
    Returns:
        tf.keras.Sequential
    '''
    data_augmentation = tf.keras.Sequential([
        tf.keras.layers.RandomFlip(mode="horizontal"),
        tf.keras.layers.RandomZoom(0.1)
    ])
    
    return data_augmentation

# %%
data_augmentation = data_augmenter()

for image, _ in train_dataset.take(1):
    plt.figure(figsize=(5, 5))
    first_image = image[0]
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        augmented_image = data_augmentation(tf.expand_dims(first_image, 0))
        plt.imshow(augmented_image[0] / 255)
        plt.axis('off')

# %%
IMG_SHAPE = IMG_SIZE + (3,)
base_model = tf.keras.applications.MobileNetV2(input_shape=IMG_SHAPE,
                                               include_top=True,
                                               weights='imagenet')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224.h5
# 14536120/14536120 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step

# %%
base_model.trainable = True

# %%
model = tf.keras.Sequential()
model.add(base_model)
model.add(tf.keras.layers.Dense(320, activation='relu'))
model.add(tf.keras.layers.Dropout(0.2))
model.add(tf.keras.layers.Dense(5, activation='softmax'))

# %%
model.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=0.001,momentum=0.9), 
      loss = tf.keras.losses.CategoricalCrossentropy(), 
      metrics=['accuracy','auc'])
print(model.summary())
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ mobilenetv2_1.00_224            │ ?                      │     3,538,984 │
# │ (Functional)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ ?                      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,538,984 (13.50 MB)
#  Trainable params: 3,504,872 (13.37 MB)
#  Non-trainable params: 34,112 (133.25 KB)
# None

# %%
epochs = 40

# Reduce learning rate when there is a change lesser than <min_delta> in <val_accuracy> for more than <patience> epochs
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor = 'val_accuracy',
                                                 mode = 'max',
                                                 min_delta = 0.01,
                                                 patience = 3,
                                                 factor = 0.25,
                                                 verbose = 1,
                                                 cooldown = 0,
                                                 min_lr = 0.00000001)

# Stop the training process when there is a change lesser than <min_delta> in <val_accuracy> for more than <patience> epochs
early_stopper = tf.keras.callbacks.EarlyStopping(monitor = 'val_accuracy',
                                                 mode = 'max',
                                                 min_delta = 0.005,
                                                 patience = 10,
                                                 verbose = 1,
                                                 restore_best_weights = True)

checkpoint_filepath = '/kaggle/working/checkpoint.model.keras'
model_checkpoint_callback = keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    monitor='val_accuracy',
    mode='max',
    save_best_only=True)

# %%
class_weights = {0: 2.5273356401384084,
 1: 5.529144587433763,
 2: 3.8061490359562273,
 3: 7.632183908045977,
 4: 33.65898617511521}

# %%
history = model.fit(train_dataset,
                    class_weight = class_weights,
                    epochs=epochs,
                    validation_data = validation_dataset,
                    callbacks=[early_stopper, reduce_lr, model_checkpoint_callback])
# Out:
# Epoch 1/40
# 457/457 ━━━━━━━━━━━━━━━━━━━━ 688s 1s/step - accuracy: 0.2001 - auc: 0.5515 - loss: 7.9717 - val_accuracy: 0.0327 - val_auc: 0.3617 - val_loss: 1.6370 - learning_rate: 0.0010
# Epoch 2/40
# 457/457 ━━━━━━━━━━━━━━━━━━━━ 663s 1s/step - accuracy: 0.1527 - auc: 0.5371 - loss: 7.8348 - val_accuracy: 0.1852 - val_auc: 0.6437 - val_loss: 1.4853 - learning_rate: 0.0010
# Epoch 3/40
# 457/457 ━━━━━━━━━━━━━━━━━━━━ 672s 1s/step - accuracy: 0.2871 - auc: 0.6536 - loss: 7.1213 - val_accuracy: 0.1852 - val_auc: 0.6346 - val_loss: 1.4824 - learning_rate: 0.0010
# Epoch 4/40
# 457/457 ━━━━━━━━━━━━━━━━━━━━ 674s 1s/step - accuracy: 0.2951 - auc: 0.6756 - loss: 6.9004 - val_accuracy: 0.1852 - val_auc: 0.6450 - val_loss: 1.4428 - learning_rate: 0.0010
# Epoch 5/40
# 457/457 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.2845 - auc: 0.6774 - loss: 6.7929
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 457/457 ━━━━━━━━━━━━━━━━━━━━ 682s 1s/step - accuracy: 0.2845 - auc: 0.6774 - loss: 6.7928 - val_accuracy: 0.1949 - val_auc: 0.6454 - val_loss: 1.4174 - learning_rate: 0.0010
# Epoch 6/40
# 457/457 ━━━━━━━━━━━━━━━━━━━━ 659s 1s/step - accuracy: 0.3331 - auc: 0.7361 - loss: 6.2496 - val_accuracy: 0.2119 - val_auc: 0.6832 - val_loss: 1.3548 - learning_rate: 2.5000e-04
# Epoch 7/40
# 457/457 ━━━━━━━━━━━━━━━━━━━━ 659s 1s/step - accuracy: 0.2985 - auc: 0.7284 - loss: 6.0570 - val_accuracy: 0.2167 - val_auc: 0.6975 - val_loss: 1.3274 - learning_rate: 2.5000e-04
# Epoch 8/40
# 457/457 ━━━━━━━━━━━━━━━━━━━━ 684s 1s/step - accuracy: 0.3177 - auc: 0.7359 - loss: 5.9575 - val_accuracy: 0.2191 - val_auc: 0.7020 - val_loss: 1.3211 - learning_rate: 2.5000e-04
# Epoch 9/40
# 457/457 ━━━━━━━━━━━━━━━━━━━━ 663s 1s/step - accuracy: 0.3323 - auc: 0.7508 - loss: 5.7792 - val_accuracy: 0.2409 - val_auc: 0.7326 - val_loss: 1.3551 - learning_rate: 2.5000e-04
# Epoch 10/40
# 457/457 ━━━━━━━━━━━━━━━━━━━━ 672s 1s/step - accuracy: 0.3508 - auc: 0.7674 - loss: 5.5652 - val_accuracy: 0.2615 - val_auc: 0.7553 - val_loss: 1.2787 - learning_rate: 2.5000e-04
# Epoch 11/40
# 457/457 ━━━━━━━━━━━━━━━━━━━━ 656s 1s/step - accuracy: 0.4194 - auc: 0.7926 - loss: 5.3278 - val_accuracy: 0.3971 - val_auc: 0.7761 - val_loss: 1.2519 - learning_rate: 2.5000e-04
# Epoch 12/40
# 457/457 ━━━━━━━━━━━━━━━━━━━━ 664s 1s/step - accuracy: 0.4505 - auc: 0.8054 - loss: 5.1147 - val_accuracy: 0.4237 - val_auc: 0.7928 - val_loss: 1.2206 - learning_rate: 2.5000e-04
# Epoch 13/40
# 457/457 ━━━━━━━━━━━━━━━━━━━━ 677s 1s/step - accuracy: 0.4819 - auc: 0.8185 - loss: 4.9481 - val_accuracy: 0.4709 - val_auc: 0.8026 - val_loss: 1.1967 - learning_rate: 2.5000e-04
# Epoch 14/40
# 457/457 ━━━━━━━━━━━━━━━━━━━━ 710s 2s/step - accuracy: 0.4883 - auc: 0.8273 - loss: 4.7832 - val_accuracy: 0.3027 - val_auc: 0.7179 - val_loss: 1.4088 - learning_rate: 2.5000e-04
# Epoch 15/40
# 457/457 ━━━━━━━━━━━━━━━━━━━━ 720s 2s/step - accuracy: 0.5170 - auc: 0.8393 - loss: 4.5596 - val_accuracy: 0.4492 - val_auc: 0.8024 - val_loss: 1.1916 - learning_rate: 2.5000e-04
# Epoch 16/40
# 457/457 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5026 - auc: 0.8385 - loss: 4.5409
# Epoch 16: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 457/457 ━━━━━━━━━━━━━━━━━━━━ 725s 1s/step - accuracy: 0.5026 - auc: 0.8385 - loss: 4.5407 - val_accuracy: 0.4383 - val_auc: 0.7995 - val_loss: 1.1840 - learning_rate: 2.5000e-04
# Epoch 17/40
# 457/457 ━━━━━━━━━━━━━━━━━━━━ 671s 1s/step - accuracy: 0.5334 - auc: 0.8574 - loss: 4.2653 - val_accuracy: 0.4709 - val_auc: 0.7992 - val_loss: 1.2015 - learning_rate: 6.2500e-05
# Epoch 18/40
# 457/457 ━━━━━━━━━━━━━━━━━━━━ 680s 1s/step - accuracy: 0.5657 - auc: 0.8675 - loss: 4.1069 - val_accuracy: 0.4649 - val_auc: 0.8005 - val_loss: 1.1797 - learning_rate: 6.2500e-05
# Epoch 19/40
# 457/457 ━━━━━━━━━━━━━━━━━━━━ 681s 1s/step - accuracy: 0.5758 - auc: 0.8739 - loss: 4.0433 - val_accuracy: 0.4831 - val_auc: 0.8152 - val_loss: 1.1520 - learning_rate: 6.2500e-05
# Epoch 20/40
# 457/457 ━━━━━━━━━━━━━━━━━━━━ 662s 1s/step - accuracy: 0.5889 - auc: 0.8785 - loss: 3.9790 - val_accuracy: 0.5424 - val_auc: 0.8415 - val_loss: 1.0929 - learning_rate: 6.2500e-05
# Epoch 21/40
# 457/457 ━━━━━━━━━━━━━━━━━━━━ 683s 1s/step - accuracy: 0.5919 - auc: 0.8818 - loss: 3.9340 - val_accuracy: 0.5484 - val_auc: 0.8402 - val_loss: 1.0911 - learning_rate: 6.2500e-05
# Epoch 22/40
# 457/457 ━━━━━━━━━━━━━━━━━━━━ 683s 1s/step - accuracy: 0.6000 - auc: 0.8848 - loss: 3.8716 - val_accuracy: 0.5412 - val_auc: 0.8397 - val_loss: 1.0936 - learning_rate: 6.2500e-05
# Epoch 23/40
# 457/457 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5862 - auc: 0.8852 - loss: 3.8374
# Epoch 23: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 457/457 ━━━━━━━━━━━━━━━━━━━━ 686s 2s/step - accuracy: 0.5862 - auc: 0.8852 - loss: 3.8374 - val_accuracy: 0.5460 - val_auc: 0.8443 - val_loss: 1.0853 - learning_rate: 6.2500e-05
# Epoch 24/40
# 457/457 ━━━━━━━━━━━━━━━━━━━━ 735s 1s/step - accuracy: 0.6022 - auc: 0.8913 - loss: 3.7811 - val_accuracy: 0.5569 - val_auc: 0.8481 - val_loss: 1.0724 - learning_rate: 1.5625e-05
# Epoch 25/40
# 457/457 ━━━━━━━━━━━━━━━━━━━━ 676s 1s/step - accuracy: 0.6034 - auc: 0.8906 - loss: 3.7509 - val_accuracy: 0.5654 - val_auc: 0.8515 - val_loss: 1.0702 - learning_rate: 1.5625e-05
# Epoch 26/40
# 457/457 ━━━━━━━━━━━━━━━━━━━━ 672s 1s/step - accuracy: 0.6136 - auc: 0.8945 - loss: 3.7536 - val_accuracy: 0.5690 - val_auc: 0.8544 - val_loss: 1.0644 - learning_rate: 1.5625e-05
# Epoch 27/40
# 457/457 ━━━━━━━━━━━━━━━━━━━━ 667s 1s/step - accuracy: 0.6150 - auc: 0.8960 - loss: 3.7199 - val_accuracy: 0.5678 - val_auc: 0.8548 - val_loss: 1.0584 - learning_rate: 1.5625e-05
# Epoch 28/40
# 457/457 ━━━━━━━━━━━━━━━━━━━━ 665s 1s/step - accuracy: 0.6174 - auc: 0.8989 - loss: 3.7032 - val_accuracy: 0.5605 - val_auc: 0.8544 - val_loss: 1.0572 - learning_rate: 1.5625e-05
# Epoch 29/40
# 457/457 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6164 - auc: 0.8953 - loss: 3.7187
# Epoch 29: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 457/457 ━━━━━━━━━━━━━━━━━━━━ 684s 1s/step - accuracy: 0.6164 - auc: 0.8953 - loss: 3.7187 - val_accuracy: 0.5605 - val_auc: 0.8548 - val_loss: 1.0579 - learning_rate: 1.5625e-05
# Epoch 30/40
# 457/457 ━━━━━━━━━━━━━━━━━━━━ 677s 1s/step - accuracy: 0.6325 - auc: 0.8999 - loss: 3.6861 - val_accuracy: 0.5678 - val_auc: 0.8551 - val_loss: 1.0567 - learning_rate: 3.9063e-06
# Epoch 31/40
# 457/457 ━━━━━━━━━━━━━━━━━━━━ 686s 1s/step - accuracy: 0.6217 - auc: 0.8989 - loss: 3.6758 - val_accuracy: 0.5763 - val_auc: 0.8554 - val_loss: 1.0549 - learning_rate: 3.9063e-06
# Epoch 32/40
# 457/457 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6339 - auc: 0.9012 - loss: 3.6697
# Epoch 32: ReduceLROnPlateau reducing learning rate to 9.765625463842298e-07.
# 457/457 ━━━━━━━━━━━━━━━━━━━━ 691s 1s/step - accuracy: 0.6339 - auc: 0.9012 - loss: 3.6697 - val_accuracy: 0.5763 - val_auc: 0.8560 - val_loss: 1.0527 - learning_rate: 3.9063e-06
# Epoch 33/40
# 457/457 ━━━━━━━━━━━━━━━━━━━━ 697s 2s/step - accuracy: 0.6308 - auc: 0.9022 - loss: 3.6710 - val_accuracy: 0.5763 - val_auc: 0.8566 - val_loss: 1.0521 - learning_rate: 9.7656e-07
# Epoch 34/40
# 457/457 ━━━━━━━━━━━━━━━━━━━━ 759s 2s/step - accuracy: 0.6179 - auc: 0.8975 - loss: 3.6828 - val_accuracy: 0.5763 - val_auc: 0.8567 - val_loss: 1.0510 - learning_rate: 9.7656e-07
# Epoch 35/40
# 457/457 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6309 - auc: 0.9003 - loss: 3.6912
# Epoch 35: ReduceLROnPlateau reducing learning rate to 2.4414063659605745e-07.
# 457/457 ━━━━━━━━━━━━━━━━━━━━ 727s 2s/step - accuracy: 0.6309 - auc: 0.9003 - loss: 3.6912 - val_accuracy: 0.5775 - val_auc: 0.8567 - val_loss: 1.0525 - learning_rate: 9.7656e-07
# Epoch 36/40
# 457/457 ━━━━━━━━━━━━━━━━━━━━ 731s 1s/step - accuracy: 0.6292 - auc: 0.9011 - loss: 3.6752 - val_accuracy: 0.5751 - val_auc: 0.8568 - val_loss: 1.0514 - learning_rate: 2.4414e-07
# Epoch 37/40
# 457/457 ━━━━━━━━━━━━━━━━━━━━ 676s 1s/step - accuracy: 0.6299 - auc: 0.9023 - loss: 3.6744 - val_accuracy: 0.5775 - val_auc: 0.8568 - val_loss: 1.0515 - learning_rate: 2.4414e-07
# Epoch 38/40
# 457/457 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6164 - auc: 0.8974 - loss: 3.6860
# Epoch 38: ReduceLROnPlateau reducing learning rate to 6.103515914901436e-08.
# 457/457 ━━━━━━━━━━━━━━━━━━━━ 678s 1s/step - accuracy: 0.6164 - auc: 0.8974 - loss: 3.6860 - val_accuracy: 0.5775 - val_auc: 0.8571 - val_loss: 1.0512 - learning_rate: 2.4414e-07
# Epoch 39/40
# 457/457 ━━━━━━━━━━━━━━━━━━━━ 681s 1s/step - accuracy: 0.6326 - auc: 0.9025 - loss: 3.6732 - val_accuracy: 0.5775 - val_auc: 0.8571 - val_loss: 1.0514 - learning_rate: 6.1035e-08
# Epoch 40/40
# 457/457 ━━━━━━━━━━━━━━━━━━━━ 672s 1s/step - accuracy: 0.6179 - auc: 0.8998 - loss: 3.6825 - val_accuracy: 0.5775 - val_auc: 0.8571 - val_loss: 1.0504 - learning_rate: 6.1035e-08
# Restoring model weights from the end of the best epoch: 31.

# %%
with open('trainHistoryDict', 'wb') as file_pi:
    pickle.dump(history.history, file_pi)

# %%
# use best model for validation and testing calculation of metrics
test_dataset = image_dataset_from_directory('/kaggle/input/preprocessing-koa-dataset/new/test',
                                             label_mode="categorical",
                                             shuffle=True,
                                             batch_size=BATCH_SIZE,
                                             image_size=IMG_SIZE)
# Out:
# Found 1656 files belonging to 5 classes.

# %%
results = model.evaluate(test_dataset)
# Out:
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 29s 277ms/step - accuracy: 0.5883 - auc: 0.8746 - loss: 1.0000

# %%
#get results
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

#plot results
#accuracy
plt.figure(figsize=(8, 8))
plt.rcParams['figure.figsize'] = [16, 9]
plt.rcParams['font.size'] = 14
plt.rcParams['axes.grid'] = True
plt.rcParams['figure.facecolor'] = 'white'
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.title(f'MobileNetV2 \nTraining and Validation Accuracy. \nTrain Accuracy: {str(acc[-1])}\nValidation Accuracy: {str(val_acc[-1])}')

#loss
plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.title(f'Training and Validation Loss. \nTrain Loss: {str(loss[-1])}\nValidation Loss: {str(val_loss[-1])}')
plt.xlabel('epoch')
plt.tight_layout(pad=3.0)
plt.show()
