# %% [markdown]
# # YOLOv8 Fine Tune

# %% [markdown]
# ## Installation

# %%
# !pip install ultralytics ipywidgets -q

# %%
import os
os.environ['WANDB_DISABLED'] = 'true'

# %%
# !wandb off
# Out:
# W&B offline. Running your script from this directory will only write metadata locally. Use wandb disabled to completely turn off W&B.

# %% [markdown]
# ## Run Script

# %%
# model.train(data='/kaggle/input/preprocessing-rfmid-dataset/RFMiD', epochs=1, imgsz=224)
# !yolo train model=yolov8x-cls.pt data="/kaggle/input/preprocessing-koa-dataset/new/" epochs=150 optimizer='SGD' lr0=0.001 plots=True patience=0
# Out:
# ...
# 100%|█████████████████████████████████████████| 110M/110M [00:00<00:00, 338MB/s]
# Ultralytics YOLOv8.1.47 🚀 Python-3.10.13 torch-2.1.2 CUDA:0 (Tesla T4, 15102MiB)
# ...
