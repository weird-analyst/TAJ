# %%
#import non tensorflow libraries
import matplotlib.pyplot as plt
import os
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import pathlib
import IPython.display as display

#import tensorflow libraries
import tensorflow as tf
from tensorflow import keras
# from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image_dataset_from_directory
import tensorflow.keras.layers as tfl
import pickle
# Out:
# 2024-04-15 22:46:42.176139: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-15 22:46:42.176287: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-15 22:46:42.345082: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
BATCH_SIZE = 16
IMG_SIZE = (224, 224)
train_dataset = image_dataset_from_directory('/kaggle/input/preprocessing-koa-dataset/new/train',
                                             label_mode="categorical",
                                             shuffle=True,
                                             batch_size=BATCH_SIZE,
                                             image_size=IMG_SIZE)
validation_dataset = image_dataset_from_directory('/kaggle/input/preprocessing-koa-dataset/new/val',
                                             label_mode="categorical",
                                             shuffle=True,
                                             batch_size=BATCH_SIZE,
                                             image_size=IMG_SIZE)
# Out:
# Found 7304 files belonging to 5 classes.
# Found 826 files belonging to 5 classes.

# %%
class_names = train_dataset.class_names

plt.figure(figsize=(5, 5))
for images, labels in train_dataset.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        print(labels[i])
#         plt.title(class_names[labels[i]])
        plt.axis("off")
# Out:
# tf.Tensor([0. 0. 0. 0. 1.], shape=(5,), dtype=float32)
# tf.Tensor([0. 0. 1. 0. 0.], shape=(5,), dtype=float32)
# tf.Tensor([0. 0. 0. 1. 0.], shape=(5,), dtype=float32)
# tf.Tensor([0. 1. 0. 0. 0.], shape=(5,), dtype=float32)
# tf.Tensor([1. 0. 0. 0. 0.], shape=(5,), dtype=float32)
# tf.Tensor([0. 1. 0. 0. 0.], shape=(5,), dtype=float32)
# tf.Tensor([0. 1. 0. 0. 0.], shape=(5,), dtype=float32)
# tf.Tensor([0. 0. 0. 1. 0.], shape=(5,), dtype=float32)
# tf.Tensor([1. 0. 0. 0. 0.], shape=(5,), dtype=float32)

# %%
def data_augmenter():
    '''
    Create a Sequential model composed of 2 layers
    Returns:
        tf.keras.Sequential
    '''
    data_augmentation = tf.keras.Sequential([
        tf.keras.layers.RandomFlip(mode="horizontal"),
        tf.keras.layers.Resizing(224,224),
        tf.keras.layers.RandomZoom(0.1)
    ])
    
    return data_augmentation

# %%
data_augmentation = data_augmenter()

for image, _ in train_dataset.take(1):
    plt.figure(figsize=(5, 5))
    first_image = image[0]
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        augmented_image = data_augmentation(tf.expand_dims(first_image, 0))
        plt.imshow(augmented_image[0] / 255)
        plt.axis('off')

# %%
IMG_SHAPE = IMG_SIZE + (3,)
base_model = tf.keras.applications.MobileNetV2(input_shape=IMG_SHAPE,
                                               include_top=True,
                                               weights='imagenet')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224.h5
# 14536120/14536120 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step

# %%
base_model.trainable = True

# %%
model = tf.keras.Sequential()
model.add(base_model)
model.add(tf.keras.layers.Dense(320, activation='relu'))
model.add(tf.keras.layers.Dropout(0.2))
model.add(tf.keras.layers.Dense(5, activation='softmax'))

# %%
model.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=0.001,momentum=0.9), 
      loss = tf.keras.losses.CategoricalCrossentropy(), 
      metrics=['accuracy','auc'])
print(model.summary())
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ mobilenetv2_1.00_224            │ ?                      │     3,538,984 │
# │ (Functional)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ ?                      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,538,984 (13.50 MB)
#  Trainable params: 3,504,872 (13.37 MB)
#  Non-trainable params: 34,112 (133.25 KB)
# None

# %%
epochs = 40

# Reduce learning rate when there is a change lesser than <min_delta> in <val_accuracy> for more than <patience> epochs
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor = 'val_accuracy',
                                                 mode = 'max',
                                                 min_delta = 0.01,
                                                 patience = 3,
                                                 factor = 0.25,
                                                 verbose = 1,
                                                 cooldown = 0,
                                                 min_lr = 0.00000001)

# Stop the training process when there is a change lesser than <min_delta> in <val_accuracy> for more than <patience> epochs
early_stopper = tf.keras.callbacks.EarlyStopping(monitor = 'val_accuracy',
                                                 mode = 'max',
                                                 min_delta = 0.005,
                                                 patience = 10,
                                                 verbose = 1,
                                                 restore_best_weights = True)

checkpoint_filepath = '/kaggle/working/checkpoint.model.keras'
model_checkpoint_callback = keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    monitor='val_accuracy',
    mode='max',
    save_best_only=True)

# %%
class_weights = {0: 2.5273356401384084,
 1: 5.529144587433763,
 2: 3.8061490359562273,
 3: 7.632183908045977,
 4: 33.65898617511521}

# %%
history = model.fit(train_dataset,
                    class_weight = class_weights,
                    epochs=epochs,
                    validation_data = validation_dataset,
                    callbacks=[early_stopper, reduce_lr, model_checkpoint_callback])
# Out:
# Epoch 1/40
# 457/457 ━━━━━━━━━━━━━━━━━━━━ 785s 2s/step - accuracy: 0.0879 - auc: 0.4398 - loss: 8.1734 - val_accuracy: 0.1864 - val_auc: 0.5336 - val_loss: 1.5972 - learning_rate: 0.0010
# Epoch 2/40
# 457/457 ━━━━━━━━━━━━━━━━━━━━ 756s 2s/step - accuracy: 0.1171 - auc: 0.5189 - loss: 8.0657 - val_accuracy: 0.0315 - val_auc: 0.3046 - val_loss: 2.2716 - learning_rate: 0.0010
# Epoch 3/40
# 457/457 ━━━━━━━━━━━━━━━━━━━━ 799s 2s/step - accuracy: 0.2433 - auc: 0.6396 - loss: 7.3653 - val_accuracy: 0.0327 - val_auc: 0.3301 - val_loss: 2.5112 - learning_rate: 0.0010
# Epoch 4/40
# 457/457 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.2618 - auc: 0.6558 - loss: 7.1756
# Epoch 4: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 457/457 ━━━━━━━━━━━━━━━━━━━━ 807s 2s/step - accuracy: 0.2618 - auc: 0.6559 - loss: 7.1748 - val_accuracy: 0.1416 - val_auc: 0.5477 - val_loss: 1.6929 - learning_rate: 0.0010
# Epoch 5/40
# 457/457 ━━━━━━━━━━━━━━━━━━━━ 803s 2s/step - accuracy: 0.2784 - auc: 0.6989 - loss: 6.4627 - val_accuracy: 0.3099 - val_auc: 0.7193 - val_loss: 1.3544 - learning_rate: 2.5000e-04
# Epoch 6/40
# 457/457 ━━━━━━━━━━━━━━━━━━━━ 804s 2s/step - accuracy: 0.3236 - auc: 0.7382 - loss: 6.1054 - val_accuracy: 0.4322 - val_auc: 0.7631 - val_loss: 1.2874 - learning_rate: 2.5000e-04
# Epoch 7/40
# 457/457 ━━━━━━━━━━━━━━━━━━━━ 795s 2s/step - accuracy: 0.3572 - auc: 0.7560 - loss: 5.8688 - val_accuracy: 0.2446 - val_auc: 0.7254 - val_loss: 1.3517 - learning_rate: 2.5000e-04
# Epoch 8/40
# 457/457 ━━━━━━━━━━━━━━━━━━━━ 805s 2s/step - accuracy: 0.3652 - auc: 0.7702 - loss: 5.6374 - val_accuracy: 0.4431 - val_auc: 0.7563 - val_loss: 1.3171 - learning_rate: 2.5000e-04
# Epoch 9/40
# 457/457 ━━━━━━━━━━━━━━━━━━━━ 799s 2s/step - accuracy: 0.4055 - auc: 0.7897 - loss: 5.3533 - val_accuracy: 0.3995 - val_auc: 0.7319 - val_loss: 1.4422 - learning_rate: 2.5000e-04
# Epoch 10/40
# 457/457 ━━━━━━━━━━━━━━━━━━━━ 807s 2s/step - accuracy: 0.4303 - auc: 0.8059 - loss: 5.1146 - val_accuracy: 0.3196 - val_auc: 0.7240 - val_loss: 1.4421 - learning_rate: 2.5000e-04
# Epoch 11/40
# 457/457 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.4605 - auc: 0.8220 - loss: 4.8697
# Epoch 11: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 457/457 ━━━━━━━━━━━━━━━━━━━━ 804s 2s/step - accuracy: 0.4605 - auc: 0.8220 - loss: 4.8695 - val_accuracy: 0.3886 - val_auc: 0.7200 - val_loss: 1.5303 - learning_rate: 2.5000e-04
# Epoch 12/40
# 457/457 ━━━━━━━━━━━━━━━━━━━━ 755s 2s/step - accuracy: 0.4765 - auc: 0.8315 - loss: 4.6721 - val_accuracy: 0.4879 - val_auc: 0.7961 - val_loss: 1.2305 - learning_rate: 6.2500e-05
# Epoch 13/40
# 457/457 ━━━━━━━━━━━━━━━━━━━━ 807s 2s/step - accuracy: 0.5158 - auc: 0.8443 - loss: 4.5385 - val_accuracy: 0.5169 - val_auc: 0.8100 - val_loss: 1.1957 - learning_rate: 6.2500e-05
# Epoch 14/40
# 457/457 ━━━━━━━━━━━━━━━━━━━━ 796s 2s/step - accuracy: 0.5166 - auc: 0.8501 - loss: 4.4696 - val_accuracy: 0.5375 - val_auc: 0.8176 - val_loss: 1.1785 - learning_rate: 6.2500e-05
# Epoch 15/40
# 457/457 ━━━━━━━━━━━━━━━━━━━━ 804s 2s/step - accuracy: 0.5255 - auc: 0.8534 - loss: 4.4013 - val_accuracy: 0.5545 - val_auc: 0.8318 - val_loss: 1.1484 - learning_rate: 6.2500e-05
# Epoch 16/40
# 457/457 ━━━━━━━━━━━━━━━━━━━━ 800s 2s/step - accuracy: 0.5362 - auc: 0.8571 - loss: 4.3338 - val_accuracy: 0.5496 - val_auc: 0.8287 - val_loss: 1.1506 - learning_rate: 6.2500e-05
# Epoch 17/40
# 457/457 ━━━━━━━━━━━━━━━━━━━━ 800s 2s/step - accuracy: 0.5436 - auc: 0.8612 - loss: 4.2445 - val_accuracy: 0.5448 - val_auc: 0.8303 - val_loss: 1.1431 - learning_rate: 6.2500e-05
# Epoch 18/40
# 457/457 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5465 - auc: 0.8617 - loss: 4.1902
# Epoch 18: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 457/457 ━━━━━━━━━━━━━━━━━━━━ 807s 2s/step - accuracy: 0.5465 - auc: 0.8617 - loss: 4.1901 - val_accuracy: 0.5484 - val_auc: 0.8345 - val_loss: 1.1407 - learning_rate: 6.2500e-05
# Epoch 19/40
# 457/457 ━━━━━━━━━━━━━━━━━━━━ 753s 2s/step - accuracy: 0.5555 - auc: 0.8699 - loss: 4.1426 - val_accuracy: 0.5400 - val_auc: 0.8357 - val_loss: 1.1277 - learning_rate: 1.5625e-05
# Epoch 20/40
# 457/457 ━━━━━━━━━━━━━━━━━━━━ 760s 2s/step - accuracy: 0.5642 - auc: 0.8716 - loss: 4.0955 - val_accuracy: 0.5436 - val_auc: 0.8351 - val_loss: 1.1312 - learning_rate: 1.5625e-05
# Epoch 21/40
# 457/457 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5735 - auc: 0.8736 - loss: 4.0892
# Epoch 21: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 457/457 ━━━━━━━━━━━━━━━━━━━━ 800s 2s/step - accuracy: 0.5735 - auc: 0.8736 - loss: 4.0891 - val_accuracy: 0.5424 - val_auc: 0.8361 - val_loss: 1.1282 - learning_rate: 1.5625e-05
# Epoch 22/40
# 457/457 ━━━━━━━━━━━━━━━━━━━━ 759s 2s/step - accuracy: 0.5690 - auc: 0.8769 - loss: 4.0525 - val_accuracy: 0.5424 - val_auc: 0.8368 - val_loss: 1.1259 - learning_rate: 3.9063e-06
# Epoch 23/40
# 457/457 ━━━━━━━━━━━━━━━━━━━━ 791s 2s/step - accuracy: 0.5668 - auc: 0.8760 - loss: 4.0588 - val_accuracy: 0.5472 - val_auc: 0.8369 - val_loss: 1.1266 - learning_rate: 3.9063e-06
# Epoch 24/40
# 457/457 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5658 - auc: 0.8754 - loss: 4.0703
# Epoch 24: ReduceLROnPlateau reducing learning rate to 9.765625463842298e-07.
# 457/457 ━━━━━━━━━━━━━━━━━━━━ 809s 2s/step - accuracy: 0.5658 - auc: 0.8754 - loss: 4.0702 - val_accuracy: 0.5460 - val_auc: 0.8371 - val_loss: 1.1260 - learning_rate: 3.9063e-06
# Epoch 25/40
# 457/457 ━━━━━━━━━━━━━━━━━━━━ 806s 2s/step - accuracy: 0.5645 - auc: 0.8764 - loss: 4.0595 - val_accuracy: 0.5424 - val_auc: 0.8364 - val_loss: 1.1267 - learning_rate: 9.7656e-07
# Epoch 25: early stopping
# Restoring model weights from the end of the best epoch: 15.

# %%
model.save("/kaggle/working/saved.model.keras")

# %%
with open('trainHistoryDict', 'wb') as file_pi:
    pickle.dump(history.history, file_pi)

# %%
# use best model for validation and testing calculation of metrics
test_dataset = image_dataset_from_directory('/kaggle/input/preprocessing-koa-dataset/new/test',
                                             label_mode="categorical",
                                             shuffle=True,
                                             batch_size=BATCH_SIZE,
                                             image_size=IMG_SIZE)
# Out:
# Found 1656 files belonging to 5 classes.

# %%
results = model.evaluate(test_dataset)
# Out:
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 34s 325ms/step - accuracy: 0.5800 - auc: 0.8497 - loss: 1.0845

# %%
#get results
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

#plot results
#accuracy
plt.figure(figsize=(8, 8))
plt.rcParams['figure.figsize'] = [16, 9]
plt.rcParams['font.size'] = 14
plt.rcParams['axes.grid'] = True
plt.rcParams['figure.facecolor'] = 'white'
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.title(f'MobileNetV2 \nTraining and Validation Accuracy. \nTrain Accuracy: {str(acc[-1])}\nValidation Accuracy: {str(val_acc[-1])}')

#loss
plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.title(f'Training and Validation Loss. \nTrain Loss: {str(loss[-1])}\nValidation Loss: {str(val_loss[-1])}')
plt.xlabel('epoch')
plt.tight_layout(pad=3.0)
plt.show()

# %%
class0_train = []
for file in os.listdir("/kaggle/input/preprocessing-koa-dataset/new/train/0/"):
    class0_train.append("/kaggle/input/preprocessing-koa-dataset/new/train/0/"+file)
class1_train = []
for file in os.listdir("/kaggle/input/preprocessing-koa-dataset/new/train/1/"):
    class1_train.append("/kaggle/input/preprocessing-koa-dataset/new/train/1/"+file)
class2_train = []
for file in os.listdir("/kaggle/input/preprocessing-koa-dataset/new/train/2/"):
    class2_train.append("/kaggle/input/preprocessing-koa-dataset/new/train/2/"+file)
class3_train = []
for file in os.listdir("/kaggle/input/preprocessing-koa-dataset/new/train/3/"):
    class3_train.append("/kaggle/input/preprocessing-koa-dataset/new/train/3/"+file)
class4_train = []
for file in os.listdir("/kaggle/input/preprocessing-koa-dataset/new/train/4/"):
    class4_train.append("/kaggle/input/preprocessing-koa-dataset/new/train/4/"+file)
class0_test = []
for file in os.listdir("/kaggle/input/preprocessing-koa-dataset/new/test/0/"):
    class0_test.append("/kaggle/input/preprocessing-koa-dataset/new/test/0/"+file)
class1_test = []
for file in os.listdir("/kaggle/input/preprocessing-koa-dataset/new/test/1/"):
    class1_test.append("/kaggle/input/preprocessing-koa-dataset/new/test/1/"+file)
class2_test = []
for file in os.listdir("/kaggle/input/preprocessing-koa-dataset/new/test/2/"):
    class2_test.append("/kaggle/input/preprocessing-koa-dataset/new/test/2/"+file)
class3_test = []
for file in os.listdir("/kaggle/input/preprocessing-koa-dataset/new/test/3/"):
    class3_test.append("/kaggle/input/preprocessing-koa-dataset/new/test/3/"+file)
class4_test = []
for file in os.listdir("/kaggle/input/preprocessing-koa-dataset/new/test/4/"):
    class4_test.append("/kaggle/input/preprocessing-koa-dataset/new/test/4/"+file)
class0_val = []
for file in os.listdir("/kaggle/input/preprocessing-koa-dataset/new/val/0/"):
    class0_val.append("/kaggle/input/preprocessing-koa-dataset/new/val/0/"+file)
class1_val = []
for file in os.listdir("/kaggle/input/preprocessing-koa-dataset/new/val/1/"):
    class1_val.append("/kaggle/input/preprocessing-koa-dataset/new/val/1/"+file)
class2_val = []
for file in os.listdir("/kaggle/input/preprocessing-koa-dataset/new/val/2/"):
    class2_val.append("/kaggle/input/preprocessing-koa-dataset/new/val/2/"+file)
class3_val = []
for file in os.listdir("/kaggle/input/preprocessing-koa-dataset/new/val/3/"):
    class3_val.append("/kaggle/input/preprocessing-koa-dataset/new/val/3/"+file)
class4_val = []
for file in os.listdir("/kaggle/input/preprocessing-koa-dataset/new/val/4/"):
    class4_val.append("/kaggle/input/preprocessing-koa-dataset/new/val/4/"+file)

# %%
import cv2
import pandas as pd

# %%
# train
y_true = []
y_preds = []

for path in class0_train:
    img = cv2.imread(path)
    img = cv2.resize(img, (224,224))
    y_true.append(0)
    y_preds.append(model(tf.expand_dims(cv2.cvtColor(img, cv2.COLOR_BGR2RGB),0))[0]._numpy().tolist())
print("DONE train_0")
for path in class1_train:
    img = cv2.imread(path)
    img = cv2.resize(img, (224,224))
    y_true.append(1)
    y_preds.append(model(tf.expand_dims(cv2.cvtColor(img, cv2.COLOR_BGR2RGB),0))[0]._numpy().tolist())
print("DONE train_1")
for path in class2_train:
    img = cv2.imread(path)
    img = cv2.resize(img, (224,224))
    y_true.append(2)
    y_preds.append(model(tf.expand_dims(cv2.cvtColor(img, cv2.COLOR_BGR2RGB),0))[0]._numpy().tolist())
print("DONE train_2")
for path in class3_train:
    img = cv2.imread(path)
    img = cv2.resize(img, (224,224))
    y_true.append(3)
    y_preds.append(model(tf.expand_dims(cv2.cvtColor(img, cv2.COLOR_BGR2RGB),0))[0]._numpy().tolist())
print("DONE train_3")
for path in class4_train:
    img = cv2.imread(path)
    img = cv2.resize(img, (224,224))
    y_true.append(4)
    y_preds.append(model(tf.expand_dims(cv2.cvtColor(img, cv2.COLOR_BGR2RGB),0))[0]._numpy().tolist())
print("DONE train_4")
# Out:
# DONE train_0
# DONE train_1
# DONE train_2
# DONE train_3
# DONE train_4

# %%
pd.DataFrame({
    'FileName': class0_train + class1_train + class2_train + class3_train + class4_train,
    'y_true': y_true,
    'm_0': [y[0] for y in y_preds],
    'm_1': [y[1] for y in y_preds],
    'm_2': [y[2] for y in y_preds],
    'm_3': [y[3] for y in y_preds],
    'm_4': [y[4] for y in y_preds]
}).to_csv("m_mobilenet_train.csv")

# %%
# val

y_true = []
y_preds = []

for path in class0_val:
    img = cv2.imread(path)
    img = cv2.resize(img, (224,224))
    y_true.append(0)
    y_preds.append(model(tf.expand_dims(cv2.cvtColor(img, cv2.COLOR_BGR2RGB),0))[0]._numpy().tolist())
print("DONE val_0")
for path in class1_val:
    img = cv2.imread(path)
    img = cv2.resize(img, (224,224))
    y_true.append(1)
    y_preds.append(model(tf.expand_dims(cv2.cvtColor(img, cv2.COLOR_BGR2RGB),0))[0]._numpy().tolist())
print("DONE val_1")
for path in class2_val:
    img = cv2.imread(path)
    img = cv2.resize(img, (224,224))
    y_true.append(2)
    y_preds.append(model(tf.expand_dims(cv2.cvtColor(img, cv2.COLOR_BGR2RGB),0))[0]._numpy().tolist())
print("DONE val_2")
for path in class3_val:
    img = cv2.imread(path)
    img = cv2.resize(img, (224,224))
    y_true.append(3)
    y_preds.append(model(tf.expand_dims(cv2.cvtColor(img, cv2.COLOR_BGR2RGB),0))[0]._numpy().tolist())
print("DONE val_3")
for path in class4_val:
    img = cv2.imread(path)
    img = cv2.resize(img, (224,224))
    y_true.append(4)
    y_preds.append(model(tf.expand_dims(cv2.cvtColor(img, cv2.COLOR_BGR2RGB),0))[0]._numpy().tolist())
print("DONE val_4")

pd.DataFrame({
    'FileName': class0_val + class1_val + class2_val + class3_val + class4_val,
    'y_true': y_true,
    'm_0': [y[0] for y in y_preds],
    'm_1': [y[1] for y in y_preds],
    'm_2': [y[2] for y in y_preds],
    'm_3': [y[3] for y in y_preds],
    'm_4': [y[4] for y in y_preds]
}).to_csv("m_mobilenet_val.csv")
# Out:
# DONE val_0
# DONE val_1
# DONE val_2
# DONE val_3
# DONE val_4

# %%
# test

y_true = []
y_preds = []

for path in class0_test:
    img = cv2.imread(path)
    img = cv2.resize(img, (224,224))
    y_true.append(0)
    y_preds.append(model(tf.expand_dims(cv2.cvtColor(img, cv2.COLOR_BGR2RGB),0))[0]._numpy().tolist())
print("DONE test_0")
for path in class1_test:
    img = cv2.imread(path)
    img = cv2.resize(img, (224,224))
    y_true.append(1)
    y_preds.append(model(tf.expand_dims(cv2.cvtColor(img, cv2.COLOR_BGR2RGB),0))[0]._numpy().tolist())
print("DONE test_1")
for path in class2_test:
    img = cv2.imread(path)
    img = cv2.resize(img, (224,224))
    y_true.append(2)
    y_preds.append(model(tf.expand_dims(cv2.cvtColor(img, cv2.COLOR_BGR2RGB),0))[0]._numpy().tolist())
print("DONE test_2")
for path in class3_test:
    img = cv2.imread(path)
    img = cv2.resize(img, (224,224))
    y_true.append(3)
    y_preds.append(model(tf.expand_dims(cv2.cvtColor(img, cv2.COLOR_BGR2RGB),0))[0]._numpy().tolist())
print("DONE test_3")
for path in class4_test:
    img = cv2.imread(path)
    img = cv2.resize(img, (224,224))
    y_true.append(4)
    y_preds.append(model(tf.expand_dims(cv2.cvtColor(img, cv2.COLOR_BGR2RGB),0))[0]._numpy().tolist())
print("DONE test_4")

pd.DataFrame({
    'FileName': class0_test + class1_test + class2_test + class3_test + class4_test,
    'y_true': y_true,
    'm_0': [y[0] for y in y_preds],
    'm_1': [y[1] for y in y_preds],
    'm_2': [y[2] for y in y_preds],
    'm_3': [y[3] for y in y_preds],
    'm_4': [y[4] for y in y_preds]
}).to_csv("m_mobilenet_test.csv")
# Out:
# DONE test_0
# DONE test_1
# DONE test_2
# DONE test_3
# DONE test_4
